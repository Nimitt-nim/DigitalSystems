# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

def tanh(x):
    return (np.exp(x) - np.exp(-x))/(np.exp(x)+np.exp(-x))

def piecewise_sigmoid(x):
    y = np.zeros(len(x))
    for i in range(len(x)):
        if (x[i]<= -5):
            y[i] = 0 
        elif ( -5<x[i]<= -2):
            y[i] = 0.0375*x[i] + 0.194
        elif (-2<x[i]<= 2):
            y[i] =  0.190*x[i] + 0.5
        elif (2<x[i]<= 5):
            y[i] =  0.0375*x[i] + 0.805
        else:
            y[i] = 1
    return y

def piecewise_tanh(x):
    return 2*piecewise_sigmoid(2*x) - 1

# %%
sr = np.arange(-10,10)
sig = sigmoid(sr)
tan = tanh(sr)
p_sig = piecewise_sigmoid(sr)
p_tanh = piecewise_tanh(sr)
plt.plot(sr,sig)
plt.plot(sr,p_sig)
plt.show()
plt.plot(sr,tan)
plt.plot(sr,p_tanh)
plt.show()
